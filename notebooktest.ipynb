# %%
import ast
import pandas as pd

filmes = pd.read_csv('movies_from_1960_to_2024.csv') #Usando Pandas para ler CSV e armazena numa variável
filmes_df = pd.DataFrame(filmes) #Criando um dataframe com os dados do CSV
display(filmes_df) #Printando os cinco primeiros filmes do dataset
# Out:
#               id                            Title  \
# 0      tt0073195                             Jaws
# 1      tt0073629    The Rocky Horror Picture Show
# 2      tt0073486  One Flew Over the Cuckoo's Nest
# 3      tt0072890                Dog Day Afternoon
# 4      tt0073692                          Shampoo
# ...          ...                              ...
# 33595  tt0094076                        The South
# 33596  tt0256664       El cabaretero y sus golfas
# 33597  tt0353261           BraveStarr: The Legend
# 33598  tt0098474                 Fighting Madam 2
# 33599  tt0096039   Saturday the 14th Strikes Back
#
#                                  Movie Link  Year Duration  MPA  Rating Votes  \
# 0      https://www.imdb.com/title/tt0073195  1975    2h 4m   PG     8.1  683K
# 1      https://www.imdb.com/title/tt0073629  1975   1h 40m    R     7.4  173K
# 2      https://www.imdb.com/title/tt0073486  1975   2h 13m    R     8.7  1.1M
# 3      https://www.imdb.com/title/tt0072890  1975    2h 5m    R     8.0  279K
# 4      https://www.imdb.com/title/tt0073692  1975   1h 50m    R     6.4   15K
# ...                                     ...   ...      ...  ...     ...   ...
# 33595  https://www.imdb.com/title/tt0094076  1988    2h 7m    R     7.3  1.1K
# 33596  https://www.imdb.com/title/tt0256664  1988   1h 25m  NaN     4.9    12
# 33597  https://www.imdb.com/title/tt0353261  1988   1h 31m   PG     6.8  1.3K
# 33598  https://www.imdb.com/title/tt0098474  1988   1h 30m  NaN     6.3   337
# 33599  https://www.imdb.com/title/tt0096039  1988   1h 18m   PG     3.1   737
#
#           budget  grossWorldWide  ...  \
# 0      7000000.0     477220580.0  ...
# 1      1200000.0     115798478.0  ...
# 2      3000000.0     109115366.0  ...
# 3      1800000.0      50002721.0  ...
# 4      4000000.0      49407734.0  ...
# ...          ...             ...  ...
# 33595        NaN             NaN  ...
# 33596        NaN             NaN  ...
# 33597        NaN             NaN  ...
# 33598        NaN             NaN  ...
# 33599        NaN             NaN  ...
#
#                                                writers  \
# 0                  ['Peter Benchley', 'Carl Gottlieb']
# 1                   ["Richard O'Brien", 'Jim Sharman']
# 2       ['Lawrence Hauben', 'Bo Goldman', 'Ken Kesey']
# 3      ['Frank Pierson', 'P.F. Kluge', 'Thomas Moore']
# 4                    ['Robert Towne', 'Warren Beatty']
# ...                                                ...
# 33595                          ['Fernando E. Solanas']
# 33596                                 ['Raúl Marcelo']
# 33597                   ['Bob Forward', 'Steve Hayes']
# 33598    ['William Hsu', 'Teresa Woo', 'Larry Dolgin']
# 33599                              ['Howard R. Cohen']
#
#                                                    stars  \
# 0      ['Roy Scheider', 'Robert Shaw', 'Richard Dreyf...
# 1      ['Tim Curry', 'Susan Sarandon', 'Barry Bostwick']
# 2      ['Jack Nicholson', 'Louise Fletcher', 'Michael...
# 3         ['Al Pacino', 'John Cazale', 'Penelope Allen']
# 4      ['Warren Beatty', 'Julie Christie', 'Goldie Ha...
# ...                                                  ...
# 33595  ['Susú Pecoraro', 'Miguel Ángel Solá', 'Philip...
# 33596  ['Raúl Ramírez', 'Raúl Marcelo', 'Marcela Davi...
# 33597       ['Charlie Adler', 'Susan Blu', 'Pat Fraley']
# 33598            ['Alex Fong', 'Moon Lee', 'Elaine Lui']
# 33599  ['Ray Walston', 'Avery Schreiber', 'Patty McCo...
#
#                                                   genres  \
# 0      ['Monster Horror', 'Sea Adventure', 'Survival'...
# 1      ['Dark Comedy', 'Raunchy Comedy', 'Rock Musica...
# 2      ['Medical Drama', 'Psychological Drama', 'Drama']
# 3      ['Heist', 'True Crime', 'Biography', 'Crime', ...
# 4                          ['Satire', 'Comedy', 'Drama']
# ...                                                  ...
# 33595                                          ['Drama']
# 33596                                         ['Comedy']
# 33597  ['Superhero', 'Action', 'Adventure', 'Animatio...
# 33598                                         ['Action']
# 33599          ['Comedy', 'Fantasy', 'Horror', 'Sci-Fi']
#
#                           countries_origin  \
# 0                        ['United States']
# 1      ['United Kingdom', 'United States']
# 2                        ['United States']
# 3                        ['United States']
# 4                        ['United States']
# ...                                    ...
# 33595              ['Argentina', 'France']
# 33596                           ['Mexico']
# 33597                    ['United States']
# 33598                        ['Hong Kong']
# 33599                    ['United States']
#
#                                        filming_locations  \
# 0      ["Water Street, Edgartown, Martha's Vineyard, ...
# 1      ['Oakley Court, Windsor Road, Oakley Green, Wi...
# 2      ['Oregon State Mental Hospital - 2600 Center S...
# 3      ['285 Prospect Park West, Brooklyn, New York C...
# 4      ['2270 Bowmont Drive, Beverly Hills, Californi...
# ...                                                  ...
# 33595      ['Buenos Aires, Federal District, Argentina']
# 33596                                                NaN
# 33597                                                NaN
# 33598                         ['Kuala Lumpur, Malaysia']
# 33599                        ['Venice, California, USA']
#
#                                     production_companies  \
# 0      ['Zanuck/Brown Productions', 'Universal Pictur...
# 1      ['Twentieth Century Fox', 'Michael White Produ...
# 2                       ['Fantasy Films', 'N.V. Zvaluw']
# 3      ['Warner Bros.', 'Artists Entertainment Complex']
# 4      ['Persky-Bright / Vista', 'Columbia Pictures',...
# ...                                                  ...
# 33595  ['Canal+', 'Cinesur (Envar El Kadri)', 'Produc...
# 33596                                                NaN
# 33597                           ['Filmation Associates']
# 33598                             ['Molesworth Limited']
# 33599                                  ['Pacific Trust']
#
#                        Languages wins nominations oscars
# 0                    ['English']    0          20      0
# 1                    ['English']    0           4      0
# 2                    ['English']    0          15      0
# 3                    ['English']    0          20      0
# 4                    ['English']    0          11      0
# ...                          ...  ...         ...    ...
# 33595      ['Spanish', 'French']    0           2      0
# 33596                ['Spanish']    0           0      0
# 33597                ['English']    0           0      0
# 33598  ['Cantonese', 'Mandarin']    0           0      0
# 33599                ['English']    0           0      0
#
# [33600 rows x 23 columns]

# %%
filmes_df.describe() #Método para obter estatísticas descritivas do DataFrame
#filmes_df.describe(include='all') # inclui todas as colunas, até os dados categóricos
# Out:
#                Year        Rating        budget  grossWorldWide  \
# count  33600.000000  33462.000000  1.181500e+04    1.822200e+04
# mean    1992.393631      6.155158  8.454320e+07    3.814961e+07
# std       18.957395      1.146070  2.866281e+09    1.210105e+08
# min     1960.000000      1.100000  1.000000e+00    1.000000e+00
# 25%     1976.000000      5.500000  2.000000e+06    1.589938e+05
# 50%     1993.000000      6.300000  9.000000e+06    2.311544e+06
# 75%     2009.000000      7.000000  2.700000e+07    2.092931e+07
# max     2024.000000      9.600000  3.000000e+11    2.923706e+09
#
#        gross_US_Canada  opening_weekend_Gross     wins   nominations  \
# count     1.757100e+04           1.552300e+04  33600.0  33600.000000
# mean      1.808236e+07           5.110082e+06      0.0      4.850357
# std       4.853181e+07           1.488319e+07      0.0     17.719188
# min       6.400000e+01           1.100000e+01      0.0      0.000000
# 25%       8.603650e+04           1.399650e+04      0.0      0.000000
# 50%       9.094110e+05           1.075360e+05      0.0      0.000000
# 75%       1.405137e+07           3.772558e+06      0.0      3.000000
# max       9.366622e+08           3.571150e+08      0.0    433.000000
#
#              oscars
# count  33600.000000
# mean       0.102619
# std        0.508687
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       11.000000

# %%
display(filmes_df[['Title', 'oscars']].sort_values(by='oscars', ascending=False).head(10)) #Listando os 10 filmes com mais Oscars do Dataset
# Out:
#                             Title  oscars
# 24803            The Color Purple      11
# 518             The Turning Point      11
# 9962                    True Grit      10
# 10484           Gangs of New York      10
# 20116             American Hustle      10
# 20683  Killers of the Flower Moon      10
# 14070   The Banshees of Inisherin       9
# 14011                       Elvis       8
# 1017             The Sand Pebbles       8
# 30114      The Remains of the Day       8

# %%
display(filmes_df.loc[14006]) #linha 14006
display(filmes_df.loc[filmes_df['Title'] == 'Oppenheimer'])
# .loc[] se assemelha ao WHERE, permite selecionar linhas dada 
# uma determinada condição
# Out:
# id                                                               tt1877830
# Title                                                           The Batman
# Movie Link                            https://www.imdb.com/title/tt1877830
# Year                                                                  2022
# Duration                                                            2h 56m
# MPA                                                                  PG-13
# Rating                                                                 7.8
# Votes                                                                 850K
# budget                                                         185000000.0
# grossWorldWide                                                 772319315.0
# gross_US_Canada                                                369345583.0
# opening_weekend_Gross                                          134008624.0
# directors                                                  ['Matt Reeves']
# writers                         ['Matt Reeves', 'Peter Craig', 'Bob Kane']
# stars                    ['Robert Pattinson', 'Zoë Kravitz', 'Jeffrey W...
# genres                   ['Action Epic', 'Epic', 'Serial Killer', 'Supe...
# countries_origin                                         ['United States']
# filming_locations           ['Necropolis Cemetery, Glasgow, Scotland, UK']
# production_companies     ['Warner Bros.', 'DC Entertainment', '6th & Id...
# Languages                       ['English', 'Spanish', 'Latin', 'Italian']
# wins                                                                     0
# nominations                                                            185
# oscars                                                                   3
# Name: 14006, dtype: object
#                id        Title                             Movie Link  Year  \
# 20654  tt15398776  Oppenheimer  https://www.imdb.com/title/tt15398776  2023
#
#       Duration MPA  Rating Votes       budget  grossWorldWide  ...  \
# 20654       3h   R     8.3  834K  100000000.0     975594978.0  ...
#
#                                                  writers  \
# 20654  ['Christopher Nolan', 'Kai Bird', 'Martin Sher...
#
#                                                  stars  \
# 20654  ['Cillian Murphy', 'Emily Blunt', 'Matt Damon']
#
#                                                   genres  \
# 20654  ['Docudrama', 'Epic', 'Historical Epic', 'Peri...
#
#                           countries_origin                filming_locations  \
# 20654  ['United States', 'United Kingdom']  ['Los Alamos, New Mexico, USA']
#
#                                     production_companies  \
# 20654  ['Universal Pictures', 'Atlas Entertainment', ...
#
#                                        Languages wins nominations oscars
# 20654  ['English', 'German', 'Italian', 'Dutch']    0         369      0
#
# [1 rows x 23 columns]

# %%
display(filmes_df.sort_values(by = 'Year', ascending=False).head(5)) #ordenando pelo ano mais recente
# Out:
#               id                   Title  \
# 8374   tt1684562            The Fall Guy
# 8564  tt28082769             September 5
# 8570  tt32561659    Bocchi the Rock! Re:
# 8569  tt10449276                Get Away
# 8568  tt10850320  Luther: Never Too Much
#
#                                  Movie Link  Year Duration    MPA  Rating  \
# 8374   https://www.imdb.com/title/tt1684562  2024    2h 6m  PG-13     6.9
# 8564  https://www.imdb.com/title/tt28082769  2024   1h 35m      R     7.1
# 8570  https://www.imdb.com/title/tt32561659  2024   1h 30m    NaN     7.6
# 8569  https://www.imdb.com/title/tt10449276  2024   1h 26m      R     5.8
# 8568  https://www.imdb.com/title/tt10850320  2024   1h 41m    NaN     8.4
#
#      Votes       budget  grossWorldWide  ...  \
# 8374  193K  125000000.0     181073291.0  ...
# 8564  1.2K          NaN        251835.0  ...
# 8570   121          NaN       3530805.0  ...
# 8569   327          NaN        179897.0  ...
# 8568   232          NaN        202796.0  ...
#
#                                               writers  \
# 8374                ['Glen A. Larson', 'Drew Pearce']
# 8564  ['Moritz Binder', 'Tim Fehlbaum', 'Alex David']
# 8570                                              NaN
# 8569                                   ['Nick Frost']
# 8568                                              NaN
#
#                                                   stars  \
# 8374  ['Ryan Gosling', 'Emily Blunt', 'Aaron Taylor-...
# 8564  ['Peter Sarsgaard', 'John Magaro', 'Ben Chaplin']
# 8570  ['Yoshino Aoyama', 'Sayumi Suzushiro', 'Saku M...
# 8569   ['Nick Frost', 'Aisling Bea', 'Sebastian Croft']
# 8568  ['Jamie Foxx', 'Mariah Carey', 'Luther Vandross']
#
#                                                  genres  \
# 8374           ['Action', 'Comedy', 'Drama', 'Romance']
# 8564  ['Docudrama', 'Period Drama', 'Tragedy', 'Dram...
# 8570  ['Anime', 'Coming-of-Age', 'Seinen', 'Slice of...
# 8569                               ['Comedy', 'Horror']
# 8568              ['Biography', 'Documentary', 'Music']
#
#                               countries_origin  \
# 8374  ['United States', 'Australia', 'Canada']
# 8564              ['Germany', 'United States']
# 8570                                 ['Japan']
# 8569                        ['United Kingdom']
# 8568       ['United Kingdom', 'United States']
#
#                            filming_locations  \
# 8374  ['Sydney, New South Wales, Australia']
# 8564            ['Munich, Bavaria, Germany']
# 8570                                     NaN
# 8569                    ['Tampere, Finland']
# 8568                                     NaN
#
#                                    production_companies  \
# 8374  ['87North', 'Australian Government', 'Entertai...
# 8564  ['BerghausWöbke Filmproduktion', 'Projected Pi...
# 8570            ['Aniplex', 'CloverWorks', 'Houbunsha']
# 8569  ['Big Safari', 'Creativity Capital', 'Inland F...
# 8568  ['Foxxhole Productions', 'Raindog Films', 'Son...
#
#                   Languages wins nominations oscars
# 8374            ['English']    0          33      0
# 8564  ['English', 'German']    0          23      0
# 8570           ['Japanese']    0           0      0
# 8569            ['English']    0           0      0
# 8568            ['English']    0           6      0
#
# [5 rows x 23 columns]

# %%
display(filmes_df.loc[filmes_df['budget'] >= 10000000000, ['Title', 'budget']].sort_values(by='budget', ascending=False).values) #recuper todos os valores da coluna Title onde os valores na coluna budget são maiores ou iguais a 10 bilhões.
# Out:
# array([['Harbin', 300000000000.0],
#        ['Along With the Gods: The Last 49 Days', 35000000000.0],
#        ['My Way', 30000000000.0],
#        ['Alienoid', 30000000000.0],
#        ['The Name of the Rose', 30000000000.0],
#        ['The Moon', 28000000000.0],
#        ['Escape from Mogadishu', 24000000000.0],
#        ['The Spy Gone North', 19000000000.0],
#        ['Life Is Beautiful', 15000000000.0],
#        ['The Great Battle', 15000000000.0],
#        ['The Host', 12215500000.0],
#        ['Decibel', 12000000000.0],
#        ['Project Wolf Hunting', 12000000000.0],
#        ['Train to Busan', 10000000000.0],
#        ['The Handmaiden', 10000000000.0]], dtype=object)

# %%
budget_df = filmes_df.sort_values(by='budget', ascending=False) #Dataframe destinado para melhor vizualização dos maiores orçamentos dos filmes
#display(filmes_df.head(2))
display(budget_df[['Title', 'budget', 'Year']].head(10))
# Out:
#                                        Title        budget  Year
# 8597                                  Harbin  3.000000e+11  2024
# 30782  Along With the Gods: The Last 49 Days  3.500000e+10  2018
# 14228                               Alienoid  3.000000e+10  2022
# 4012                                  My Way  3.000000e+10  2011
# 19685                   The Name of the Rose  3.000000e+10  1986
# 20958                               The Moon  2.800000e+10  2023
# 22908                  Escape from Mogadishu  2.400000e+10  2021
# 30833                     The Spy Gone North  1.900000e+10  2018
# 30836                       The Great Battle  1.500000e+10  2018
# 28980                      Life Is Beautiful  1.500000e+10  1997

# %%
# Descobrindo os maiores orçamentos dos filmes do maior para o menor
# B -> Bilhões / M -> Milhões / K -> Mil 

def convert_to_str(budget):
    if isinstance(budget, (int, float)):
        
        if budget >= 1_000_000_000:  # Se for maior ou igual a 1 bilhão
            return f"{budget / 1_000_000_000:.1f}B".replace(".0", "")  # Converte para "M"
        
        elif budget >= 1_000_000:  # Se for maior ou igual a 1 milhão
            return f"{budget / 1_000_000:.1f}M".replace(".0", "")  # Converte para "M"
        
        elif budget >= 1_000:  # Se for maior ou igual a 1 milhar
            return f"{budget / 1_000:.1f}K".replace(".0", "")  # Converte para "K"
        
        else:
            return str(float(budget))  #se for menor que 1000 Mantém como float
    return str(budget)  # Se já for string, retorna sem alteração


budget_df['budget'] = budget_df['budget'].apply(convert_to_str) # Aplicando a conversão à coluna "budget"

display(budget_df[['Title', 'budget', 'Year']].head(20))
# Out:
#                                        Title budget  Year
# 8597                                  Harbin   300B  2024
# 30782  Along With the Gods: The Last 49 Days    35B  2018
# 14228                               Alienoid    30B  2022
# 4012                                  My Way    30B  2011
# 19685                   The Name of the Rose    30B  1986
# 20958                               The Moon    28B  2023
# 22908                  Escape from Mogadishu    24B  2021
# 30833                     The Spy Gone North    19B  2018
# 30836                       The Great Battle    15B  2018
# 28980                      Life Is Beautiful    15B  1997
# 15310                               The Host  12.2B  2006
# 14356                   Project Wolf Hunting    12B  2022
# 14288                                Decibel    12B  2022
# 23963                         Train to Busan    10B  2016
# 23965                         The Handmaiden    10B  2016
# 31511                    Ask Me If I'm Happy     7B  2000
# 8415                           Kalki 2898 AD     6B  2024
# 30720                                    2.0   5.7B  2018
# 20308        The Tale of The Princess Kaguya     5B  2013
# 14098                Ponniyin Selvan: Part I     5B  2022

# %%
# Função que retorna a string que mais se repete em uma coluna de um DataFrame.

def string_mais_repetida(df, coluna):
    
    # Verifica se a coluna existe no DataFrame
    if coluna not in df.columns:
        raise ValueError(f"A coluna '{coluna}' não existe no DataFrame.")

    # Conta a frequência de cada valor na coluna
    contagem = df[coluna].value_counts()
    print(contagem)

    # Retorna a string mais repetida e sua contagem
    string_mais_comum = contagem.idxmax()
    contagem_mais_comum = contagem.max()

    return string_mais_comum, contagem_mais_comum

# %%
#Diretores com mais filmes

string, contagem = string_mais_repetida(filmes_df, 'directors')
print(f'\nO diretor com mais filmes desse dataset é {string}, com {contagem} filmes registrados no imdb')
# Out:
# directors
# ['Jesús Franco']                         82
# ['Woody Allen']                          46
# ["Joe D'Amato"]                          43
# ['Sidney Lumet']                         40
# ['Clint Eastwood']                       40
#                                          ..
# ['André Michel']                          1
# ['Alphonse Gimeno', 'Michel Wichard']     1
# ['Alfred Weidenmann']                     1
# ['Yûgo Serikawa', 'William Ross']         1
# ['Tom Tataranowicz']                      1
# Name: count, Length: 14520, dtype: int64
#
# O diretor com mais filmes desse dataset é ['Jesús Franco'], com 82 filmes registrados no imdb

# %%
filmes_df['directors']
# Out:
# 0           ['Steven Spielberg']
# 1                ['Jim Sharman']
# 2               ['Milos Forman']
# 3               ['Sidney Lumet']
# 4                  ['Hal Ashby']
#                   ...
# 33595    ['Fernando E. Solanas']
# 33596           ['Raúl Ramírez']
# 33597       ['Tom Tataranowicz']
# 33598             ['Teresa Woo']
# 33599        ['Howard R. Cohen']
# Name: directors, Length: 33600, dtype: object

# %%
#Tratando os dado da coluna 'directors', type lista -> str.

filmes_df['directors'] = filmes_df['directors'].fillna('[]') # Substituir NaN por listas vazias
filmes_df['directors'] = filmes_df['directors'].apply(ast.literal_eval)# Converte strings que representam listas em listas reais
filmes_df['directors'] = filmes_df['directors'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None) # Extrai o primeiro nome da lista, se a lista não estiver vazia

# %%
filmes_df['directors']
# Out:
# 0           Steven Spielberg
# 1                Jim Sharman
# 2               Milos Forman
# 3               Sidney Lumet
# 4                  Hal Ashby
#                 ...
# 33595    Fernando E. Solanas
# 33596           Raúl Ramírez
# 33597       Tom Tataranowicz
# 33598             Teresa Woo
# 33599        Howard R. Cohen
# Name: directors, Length: 33600, dtype: object

# %%
# Lista dos filmes de cada diretor ordenando por ano

directorsFilms = filmes_df.loc[
    filmes_df['directors'].str.strip() == 'Steven Spielberg', 
    ['id', 'Title', 'Year', 'budget', 'oscars']
].sort_values(by='Year', ascending=False) #Exemplo: Steven Spielberg

display(directorsFilms)
print(f"total: {len(directorsFilms)} filmes")
# Out:
#                id                                              Title  Year  \
# 14057  tt14208870                                      The Fabelmans  2022
# 22782   tt3581652                                    West Side Story  2021
# 30573   tt1677720                                   Ready Player One  2018
# 3138    tt6294822                                           The Post  2017
# 23809   tt3691740                                            The BFG  2016
# 22288   tt3682448                                    Bridge of Spies  2015
# 27852   tt0367882  Indiana Jones and the Kingdom of the Crystal S...  2008
# 16103   tt0407304                                  War of the Worlds  2005
# 16161   tt0408306                                             Munich  2005
# 6234    tt0362227                                       The Terminal  2004
# 10460   tt0264464                                Catch Me If You Can  2002
# 10466   tt0181689                                    Minority Report  2002
# 24277   tt0212720                       A.I. Artificial Intelligence  2001
# 19100   tt0120815                                Saving Private Ryan  1998
# 28997   tt0118607                                            Amistad  1997
# 28952   tt0119567                      The Lost World: Jurassic Park  1997
# 30050   tt0107290                                      Jurassic Park  1993
# 30058   tt0108052                                   Schindler's List  1993
# 8955    tt0102057                                               Hook  1991
# 9478    tt0096794                                             Always  1989
# 9451    tt0097576                 Indiana Jones and the Last Crusade  1989
# 12500   tt0092965                                  Empire of the Sun  1987
# 24803   tt0088939                                   The Color Purple  1985
# 5152    tt0087469               Indiana Jones and the Temple of Doom  1984
# 1500    tt0083866                         E.T. the Extra-Terrestrial  1982
# 21750   tt0082971                            Raiders of the Lost Ark  1981
# 16622   tt0078723                                               1941  1979
# 501     tt0075860                 Close Encounters of the Third Kind  1977
# 0       tt0073195                                               Jaws  1975
# 17617   tt0072226                              The Sugarland Express  1974
# 26436   tt0059181                                          Firelight  1964
#
#             budget  oscars
# 14057   40000000.0       7
# 22782  100000000.0       0
# 30573  175000000.0       1
# 3138    50000000.0       2
# 23809  140000000.0       1
# 22288   40000000.0       0
# 27852  185000000.0       1
# 16103  132000000.0       3
# 16161   70000000.0       5
# 6234    60000000.0       0
# 10460   52000000.0       2
# 10466  102000000.0       1
# 24277  100000000.0       2
# 19100   70000000.0       0
# 28997   36000000.0       4
# 28952   73000000.0       1
# 30050   63000000.0       0
# 30058   22000000.0       0
# 8955    70000000.0       5
# 9478    31000000.0       0
# 9451    48000000.0       0
# 12500   35000000.0       6
# 24803   15000000.0      11
# 5152    28000000.0       0
# 1500    10500000.0       0
# 21750   18000000.0       0
# 16622   35000000.0       3
# 501     20000000.0       0
# 0        7000000.0       0
# 17617    3000000.0       0
# 26436        400.0       0
# total: 31 filmes

# %%
# Contando quantas linguagens são mais presentes nos filmes
contagem = filmes_df['Languages'].value_counts()

#percentual das linguagens
percentual = filmes_df['Languages'].value_counts(normalize = True) * 100

percentual_df = pd.DataFrame({
    'Frequência': contagem,
    'Porcentagem (%)': percentual
})


percentual_df.head(20) #Porcentagem e qunatidade de filmes em cada língua ou combinação delas
# Out:
#             Frequência  Porcentagem (%)
# Languages
# English          21228        64.082594
# French            1960         5.916803
# Italian           1721         5.195315
# Hindi             1259         3.800640
# Spanish           1061         3.202922
# Japanese           998         3.012739
# German             750         2.264083
# Mandarin           409         1.234680
# Cantonese          327         0.987140
# Korean             248         0.748657
# Swedish            241         0.727525
# Danish             228         0.688281
# Russian            226         0.682244
# Turkish            188         0.567530
# Portuguese         183         0.552436
# Greek              159         0.479986
# Czech              132         0.398479
# Polish             111         0.335084
# Tamil              110         0.332065
# Norwegian           94         0.283765

# %%
filmes_df['Languages'] = filmes_df['Languages'].fillna('[]') # Substituir NaN por listas vazias
filmes_df['Languages'] = filmes_df['Languages'].apply(ast.literal_eval)# Converte strings que representam listas em listas reais
filmes_df['Languages'] = filmes_df['Languages'].apply(lambda x: x[0] if isinstance(x, list) and len(x) > 0 else None) # Extrai o primeiro nome da lista, se a lista não estiver vazia

# %%
#Filmes Brasileiros mais premiados

titles = filmes_df.loc[filmes_df['Languages'] == 'Portuguese', 'Title']
years = filmes_df.loc[filmes_df['Languages'] == 'Portuguese', 'Year']
directors = filmes_df.loc[filmes_df['Languages'] == 'Portuguese', 'directors']
oscar = filmes_df.loc[filmes_df['Languages'] == 'Portuguese', 'oscars']

filmesPT_df = pd.DataFrame({
    'Títulos': titles,
    'Diretores': directors,
    'Ano': years,
    'Oscars': oscar
})
#filmesPT_df.set_index() 

filmesPT_df.sort_values(by='Oscars', ascending=False).head(8)
# Out:
#                               Títulos           Diretores   Ano  Oscars
# 10602                     City of God  Fernando Meirelles  2002       4
# 19239                 Central Station       Walter Salles  1998       2
# 13658                  The Given Word      Anselmo Duarte  1962       1
# 29170          Four Days in September       Bruno Barreto  1997       1
# 24622                  Behind the Sun       Walter Salles  2001       1
# 20429           The Boy and the World           Alê Abreu  2013       1
# 18727  Dona Flor and Her Two Husbands       Bruno Barreto  1976       1
# 10222                      Waste Land         Lucy Walker  2010       1

# %%
filmesPT_df.sort_values(by='Ano', ascending=False).head(8) #Filmes Brasileiros mais recentes
# Out:
#                 Títulos                Diretores   Ano  Oscars
# 8725     I'm Still Here            Walter Salles  2024       0
# 8784     A Dog's Will 2              Guel Arraes  2024       0
# 21137  Burning Betrayal            Diego Freitas  2023       0
# 14414        Tommy Guns         Carlos Conceição  2022       0
# 14279     The Territory               Alex Pritz  2022       0
# 23105    The Pink Cloud             Iuli Gerbase  2021       0
# 23096            Medusa  Anita Rocha da Silveira  2021       0
# 23035    Private Desert             Aly Muritiba  2021       0

# %%
f = pd.crosstab(filmes_df.Year,
                filmes_df['Title'],
                aggfunc = 'mean',
                values = filmes_df['budget'])
display(f.sort_values(by='Year', ascending=False).head(24))
# Out:
# Title  '85: The Greatest Team in Football History  'Round Midnight  \
# Year
# 2024                                          NaN              NaN
# 2023                                          NaN              NaN
# 2022                                          NaN              NaN
# 2021                                          NaN              NaN
# 2020                                          NaN              NaN
# 2019                                          NaN              NaN
# 2018                                          NaN              NaN
# 2017                                          NaN              NaN
# 2016                                     650000.0              NaN
# 2015                                          NaN              NaN
# 2014                                          NaN              NaN
# 2013                                          NaN              NaN
# 2012                                          NaN              NaN
# 2011                                          NaN              NaN
# 2010                                          NaN              NaN
# 2009                                          NaN              NaN
# 2008                                          NaN              NaN
# 2007                                          NaN              NaN
# 2006                                          NaN              NaN
# 2005                                          NaN              NaN
# 2004                                          NaN              NaN
# 2003                                          NaN              NaN
# 2002                                          NaN              NaN
# 2001                                          NaN              NaN
#
# Title  'Til There Was You  'night, Mother  (T)Raumschiff Surprise - Periode 1  \
# Year
# 2024                  NaN             NaN                                 NaN
# 2023                  NaN             NaN                                 NaN
# 2022                  NaN             NaN                                 NaN
# 2021                  NaN             NaN                                 NaN
# 2020                  NaN             NaN                                 NaN
# 2019                  NaN             NaN                                 NaN
# 2018                  NaN             NaN                                 NaN
# 2017                  NaN             NaN                                 NaN
# 2016                  NaN             NaN                                 NaN
# 2015                  NaN             NaN                                 NaN
# 2014                  NaN             NaN                                 NaN
# 2013                  NaN             NaN                                 NaN
# 2012                  NaN             NaN                                 NaN
# 2011                  NaN             NaN                                 NaN
# 2010                  NaN             NaN                                 NaN
# 2009                  NaN             NaN                                 NaN
# 2008                  NaN             NaN                                 NaN
# 2007                  NaN             NaN                                 NaN
# 2006                  NaN             NaN                                 NaN
# 2005                  NaN             NaN                                 NaN
# 2004                  NaN             NaN                           9000000.0
# 2003                  NaN             NaN                                 NaN
# 2002                  NaN             NaN                                 NaN
# 2001                  NaN             NaN                                 NaN
#
# Title  *batteries not included  1,000 Times Good Night  10 Cloverfield Lane  \
# Year
# 2024                       NaN                     NaN                  NaN
# 2023                       NaN                     NaN                  NaN
# 2022                       NaN                     NaN                  NaN
# 2021                       NaN                     NaN                  NaN
# 2020                       NaN                     NaN                  NaN
# 2019                       NaN                     NaN                  NaN
# 2018                       NaN                     NaN                  NaN
# 2017                       NaN                     NaN                  NaN
# 2016                       NaN                     NaN           15000000.0
# 2015                       NaN                     NaN                  NaN
# 2014                       NaN                     NaN                  NaN
# 2013                       NaN               5284200.0                  NaN
# 2012                       NaN                     NaN                  NaN
# 2011                       NaN                     NaN                  NaN
# 2010                       NaN                     NaN                  NaN
# 2009                       NaN                     NaN                  NaN
# 2008                       NaN                     NaN                  NaN
# 2007                       NaN                     NaN                  NaN
# 2006                       NaN                     NaN                  NaN
# 2005                       NaN                     NaN                  NaN
# 2004                       NaN                     NaN                  NaN
# 2003                       NaN                     NaN                  NaN
# 2002                       NaN                     NaN                  NaN
# 2001                       NaN                     NaN                  NaN
#
# Title  10 Days with Dad  10 Questions for the Dalai Lama  ...  Zulu  \
# Year                                                      ...
# 2024                NaN                              NaN  ...   NaN
# 2023                NaN                              NaN  ...   NaN
# 2022                NaN                              NaN  ...   NaN
# 2021                NaN                              NaN  ...   NaN
# 2020          8500000.0                              NaN  ...   NaN
# 2019                NaN                              NaN  ...   NaN
# 2018                NaN                              NaN  ...   NaN
# 2017                NaN                              NaN  ...   NaN
# 2016                NaN                              NaN  ...   NaN
# 2015                NaN                              NaN  ...   NaN
# 2014                NaN                              NaN  ...   NaN
# 2013                NaN                              NaN  ...   NaN
# 2012                NaN                              NaN  ...   NaN
# 2011                NaN                              NaN  ...   NaN
# 2010                NaN                              NaN  ...   NaN
# 2009                NaN                              NaN  ...   NaN
# 2008                NaN                              NaN  ...   NaN
# 2007                NaN                              NaN  ...   NaN
# 2006                NaN                         100000.0  ...   NaN
# 2005                NaN                              NaN  ...   NaN
# 2004                NaN                              NaN  ...   NaN
# 2003                NaN                              NaN  ...   NaN
# 2002                NaN                              NaN  ...   NaN
# 2001                NaN                              NaN  ...   NaN
#
# Title     [Rec]²  eXistenZ  tick, tick... BOOM!         xXx  \
# Year
# 2024         NaN       NaN                  NaN         NaN
# 2023         NaN       NaN                  NaN         NaN
# 2022         NaN       NaN                  NaN         NaN
# 2021         NaN       NaN           55000000.0         NaN
# 2020         NaN       NaN                  NaN         NaN
# 2019         NaN       NaN                  NaN         NaN
# 2018         NaN       NaN                  NaN         NaN
# 2017         NaN       NaN                  NaN         NaN
# 2016         NaN       NaN                  NaN         NaN
# 2015         NaN       NaN                  NaN         NaN
# 2014         NaN       NaN                  NaN         NaN
# 2013         NaN       NaN                  NaN         NaN
# 2012         NaN       NaN                  NaN         NaN
# 2011         NaN       NaN                  NaN         NaN
# 2010         NaN       NaN                  NaN         NaN
# 2009   5600000.0       NaN                  NaN         NaN
# 2008         NaN       NaN                  NaN         NaN
# 2007         NaN       NaN                  NaN         NaN
# 2006         NaN       NaN                  NaN         NaN
# 2005         NaN       NaN                  NaN         NaN
# 2004         NaN       NaN                  NaN         NaN
# 2003         NaN       NaN                  NaN         NaN
# 2002         NaN       NaN                  NaN  70000000.0
# 2001         NaN       NaN                  NaN         NaN
#
# Title  xXx: Return of Xander Cage  xXx: State of the Union  Ángel de fuego  \
# Year
# 2024                          NaN                      NaN             NaN
# 2023                          NaN                      NaN             NaN
# 2022                          NaN                      NaN             NaN
# 2021                          NaN                      NaN             NaN
# 2020                          NaN                      NaN             NaN
# 2019                          NaN                      NaN             NaN
# 2018                          NaN                      NaN             NaN
# 2017                   85000000.0                      NaN             NaN
# 2016                          NaN                      NaN             NaN
# 2015                          NaN                      NaN             NaN
# 2014                          NaN                      NaN             NaN
# 2013                          NaN                      NaN             NaN
# 2012                          NaN                      NaN             NaN
# 2011                          NaN                      NaN             NaN
# 2010                          NaN                      NaN             NaN
# 2009                          NaN                      NaN             NaN
# 2008                          NaN                      NaN             NaN
# 2007                          NaN                      NaN             NaN
# 2006                          NaN                      NaN             NaN
# 2005                          NaN              113000000.0             NaN
# 2004                          NaN                      NaN             NaN
# 2003                          NaN                      NaN             NaN
# 2002                          NaN                      NaN             NaN
# 2001                          NaN                      NaN             NaN
#
# Title    Æon Flux  Évocateur: The Morton Downey Jr. Movie
# Year
# 2024          NaN                                     NaN
# 2023          NaN                                     NaN
# 2022          NaN                                     NaN
# 2021          NaN                                     NaN
# 2020          NaN                                     NaN
# 2019          NaN                                     NaN
# 2018          NaN                                     NaN
# 2017          NaN                                     NaN
# 2016          NaN                                     NaN
# 2015          NaN                                     NaN
# 2014          NaN                                     NaN
# 2013          NaN                                     NaN
# 2012          NaN                                300000.0
# 2011          NaN                                     NaN
# 2010          NaN                                     NaN
# 2009          NaN                                     NaN
# 2008          NaN                                     NaN
# 2007          NaN                                     NaN
# 2006          NaN                                     NaN
# 2005   62000000.0                                     NaN
# 2004          NaN                                     NaN
# 2003          NaN                                     NaN
# 2002          NaN                                     NaN
# 2001          NaN                                     NaN
#
# [24 rows x 11448 columns]

# %%
filmes_df.sort_values(by='Year', ascending=False)
# Out:
#                id                    Title  \
# 8374    tt1684562             The Fall Guy
# 8564   tt28082769              September 5
# 8570   tt32561659     Bocchi the Rock! Re:
# 8569   tt10449276                 Get Away
# 8568   tt10850320   Luther: Never Too Much
# ...           ...                      ...
# 29676   tt0054337       The Haunted Castle
# 29675   tt0054351        The Subterraneans
# 29674   tt0054296  Seven Ways from Sundown
# 29673   tt0054122   Night and Fog in Japan
# 30002   tt0122461       Un dollaro di fifa
#
#                                   Movie Link  Year Duration       MPA  Rating  \
# 8374    https://www.imdb.com/title/tt1684562  2024    2h 6m     PG-13     6.9
# 8564   https://www.imdb.com/title/tt28082769  2024   1h 35m         R     7.1
# 8570   https://www.imdb.com/title/tt32561659  2024   1h 30m       NaN     7.6
# 8569   https://www.imdb.com/title/tt10449276  2024   1h 26m         R     5.8
# 8568   https://www.imdb.com/title/tt10850320  2024   1h 41m       NaN     8.4
# ...                                      ...   ...      ...       ...     ...
# 29676   https://www.imdb.com/title/tt0054337  1960   1h 37m       NaN     6.2
# 29675   https://www.imdb.com/title/tt0054351  1960   1h 29m       NaN     5.0
# 29674   https://www.imdb.com/title/tt0054296  1960   1h 27m  Approved     6.8
# 29673   https://www.imdb.com/title/tt0054122  1960   1h 47m       NaN     6.8
# 30002   https://www.imdb.com/title/tt0122461  1960   1h 30m       NaN     4.8
#
#       Votes       budget  grossWorldWide  ...  \
# 8374   193K  125000000.0     181073291.0  ...
# 8564   1.2K          NaN        251835.0  ...
# 8570    121          NaN       3530805.0  ...
# 8569    327          NaN        179897.0  ...
# 8568    232          NaN        202796.0  ...
# ...     ...          ...             ...  ...
# 29676   598          NaN             NaN  ...
# 29675   355     931724.0             NaN  ...
# 29674  1.3K     500000.0             NaN  ...
# 29673   898          NaN             NaN  ...
# 30002    38          NaN             NaN  ...
#
#                                                  writers  \
# 8374                   ['Glen A. Larson', 'Drew Pearce']
# 8564     ['Moritz Binder', 'Tim Fehlbaum', 'Alex David']
# 8570                                                 NaN
# 8569                                      ['Nick Frost']
# 8568                                                 NaN
# ...                                                  ...
# 29676                  ['Günter Neumann', 'Heinz Pauck']
# 29675                    ['Jack Kerouac', 'Robert Thom']
# 29674                                 ['Clair Huffaker']
# 29673                ['Toshirô Ishidô', 'Nagisa Ôshima']
# 30002  ['Mario Guerra', 'Giulio Scarnicci', 'Enzo Tar...
#
#                                                    stars  \
# 8374   ['Ryan Gosling', 'Emily Blunt', 'Aaron Taylor-...
# 8564   ['Peter Sarsgaard', 'John Magaro', 'Ben Chaplin']
# 8570   ['Yoshino Aoyama', 'Sayumi Suzushiro', 'Saku M...
# 8569    ['Nick Frost', 'Aisling Bea', 'Sebastian Croft']
# 8568   ['Jamie Foxx', 'Mariah Carey', 'Luther Vandross']
# ...                                                  ...
# 29676  ['Liselotte Pulver', 'Heinz Baumann', 'Hanne W...
# 29675  ['Leslie Caron', 'George Peppard', 'Janice Rule']
# 29674  ['Audie Murphy', 'Barry Sullivan', 'Venetia St...
# 29673  ['Miyuki Kuwano', 'Fumio Watanabe', 'Masahiko ...
# 30002  ['Ugo Tognazzi', 'Walter Chiari', 'Mario Carot...
#
#                                                   genres  \
# 8374            ['Action', 'Comedy', 'Drama', 'Romance']
# 8564   ['Docudrama', 'Period Drama', 'Tragedy', 'Dram...
# 8570   ['Anime', 'Coming-of-Age', 'Seinen', 'Slice of...
# 8569                                ['Comedy', 'Horror']
# 8568               ['Biography', 'Documentary', 'Music']
# ...                                                  ...
# 29676                   ['Comedy', 'Fantasy', 'Musical']
# 29675                                          ['Drama']
# 29674                   ['Classical Western', 'Western']
# 29673                                          ['Drama']
# 30002         ['Spaghetti Western', 'Comedy', 'Western']
#
#                                countries_origin  \
# 8374   ['United States', 'Australia', 'Canada']
# 8564               ['Germany', 'United States']
# 8570                                  ['Japan']
# 8569                         ['United Kingdom']
# 8568        ['United Kingdom', 'United States']
# ...                                         ...
# 29676                          ['West Germany']
# 29675                         ['United States']
# 29674                         ['United States']
# 29673                                 ['Japan']
# 30002                                 ['Italy']
#
#                             filming_locations  \
# 8374   ['Sydney, New South Wales, Australia']
# 8564             ['Munich, Bavaria, Germany']
# 8570                                      NaN
# 8569                     ['Tampere, Finland']
# 8568                                      NaN
# ...                                       ...
# 29676     ['Aschaffenburg, Bavaria, Germany']
# 29675      ['San Francisco, California, USA']
# 29674        ['Red Rock Canyon, Nevada, USA']
# 29673                                     NaN
# 30002                                     NaN
#
#                                     production_companies  \
# 8374   ['87North', 'Australian Government', 'Entertai...
# 8564   ['BerghausWöbke Filmproduktion', 'Projected Pi...
# 8570             ['Aniplex', 'CloverWorks', 'Houbunsha']
# 8569   ['Big Safari', 'Creativity Capital', 'Inland F...
# 8568   ['Foxxhole Productions', 'Raindog Films', 'Son...
# ...                                                  ...
# 29676                                ['Georg Witt-Film']
# 29675                      ['Metro-Goldwyn-Mayer (MGM)']
# 29674          ['Universal International Pictures (UI)']
# 29673                                       ['Shochiku']
# 30002                    ['Cineproduzione Emo Bistolfi']
#
#                    Languages wins nominations oscars
# 8374             ['English']    0          33      0
# 8564   ['English', 'German']    0          23      0
# 8570            ['Japanese']    0           0      0
# 8569             ['English']    0           0      0
# 8568             ['English']    0           6      0
# ...                      ...  ...         ...    ...
# 29676             ['German']    0           3      0
# 29675            ['English']    0           0      0
# 29674            ['English']    0           0      0
# 29673           ['Japanese']    0           0      0
# 30002            ['Italian']    0           0      0
#
# [33600 rows x 23 columns]
